# %% [markdown]
# # CS5489 - Tutorial 9
# ## Face Detection with CNNs
#
# In the previous tutorial, you used an MLP to detect a face in a small image patch.
# In this tutorial you will train a CNN instead of an MLP.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import matplotlib_inline  # setup output image format

matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import matplotlib.pyplot as plt
from numpy import *
from sklearn import *
import os
import zipfile
import fnmatch

random.seed(100)
import skimage.io
import skimage.transform
from scipy import ndimage

# %% [markdown]
# Next we will load keras and tensorflow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

K.set_image_data_format('channels_last')
import sys

print("Python:", sys.version, "Keras:", keras.__version__, "TF:", tf.__version__)
# Out:
# Python: 3.8.16 | packaged by conda-forge | (default, Feb  1 2023, 15:53:35) [MSC v.1929 64 bit (AMD64)] Keras: 2.11.0 TF: 2.11.1

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the images.  Download `faces.zip`, and place it in the same directory as this ipynb file.  **Do not unzip it.** Then run the following cell to load the images.

# %%
imgdata = {'train': [], 'test': []}
classes = {'train': [], 'test': []}

# the dataset is too big, so subsample the training and test sets...
# reduce training set by a factor of 4
train_subsample = 1
train_counter = [0, 0]
# maximum number of samples in each class for test set
test_maxsample = 472
test_counter = [0, 0]

# load the zip file
filename = 'faces.zip'
zfile = zipfile.ZipFile(filename, 'r')

for name in zfile.namelist():
    # check file name matches
    if fnmatch.fnmatch(name, "faces/*/*/*.png"):

        # filename is : faces/train/face/fname.png
        (fdir1, fname) = os.path.split(name)  # get file name
        (fdir2, fclass) = os.path.split(fdir1)  # get class (face, nonface)
        (fdir3, fset) = os.path.split(fdir2)  # get training/test set
        # class 1 = face; class 0 = non-face
        myclass = int(fclass == "face")

        loadme = False
        if fset == 'train':
            if (train_counter[myclass] % train_subsample) == 0:
                loadme = True
            train_counter[myclass] += 1
        elif fset == 'test':
            if test_counter[myclass] < test_maxsample:
                loadme = True
            test_counter[myclass] += 1

        if (loadme):
            # open file in memory, and parse as an image
            myfile = zfile.open(name)
            #img = matplotlib.image.imread(myfile)
            img = skimage.io.imread(myfile, as_gray=True)
            myfile.close()

            # append data
            imgdata[fset].append(img)
            classes[fset].append(myclass)

zfile.close()
imgsize = img.shape

print(len(imgdata['train']))
print(len(imgdata['test']))
trainclass2start = sum(classes['train'])
# Out:
# 6977
# 944

# %% [markdown]
# Next we will convert the list of images into a block (array) of images for easier processing.

# %%
# convert list to numpy array
trainY = asarray(classes['train'])
testY = asarray(classes['test'])

# convert class labels to binary indicators
trainYb = keras.utils.to_categorical(trainY)
testYb = keras.utils.to_categorical(testY)

# convert list of ndarray to ndarray
trainI = asarray(imgdata['train']).reshape((6977, 19, 19, 1))
testI = asarray(imgdata['test']).reshape((944, 19, 19, 1))

# cleanup memory
del imgdata

# shuffle the data (since it is in order by class)
random.seed(123)
inds1 = random.permutation(len(trainI)).tolist()
inds2 = random.permutation(len(testI)).tolist()
trainYb = trainYb[inds1]
testYb = testYb[inds2]
trainY = trainY[inds1]
testY = testY[inds2]
trainI = trainI[inds1]
testI = testI[inds2]

print(trainI.shape)
print(testI.shape)
# Out:
# (6977, 19, 19, 1)
# (944, 19, 19, 1)

# %% [markdown]
# Each image is a 19x19x1 array of pixel values.  The last dimension is the number of channels in the image - in this case the image is grayscale, so there is only 1 channel.  Run the below code to show an example:

# %%
print(img.shape)
plt.subplot(1, 2, 1)
plt.imshow(squeeze(trainI[1]), cmap='gray', interpolation='nearest')
plt.title("face sample")
plt.subplot(1, 2, 2)
plt.imshow(squeeze(trainI[2]), cmap='gray', interpolation='nearest')
plt.title("non-face sample")
plt.show()
# Out:
# (19, 19)

# %% [markdown]
# Run the below code to show more images!

# %%
# function to make an image montage
def image_montage(X, imsize=None, maxw=10):
    """X can be a list of images, or a matrix of vectorized images.
      Specify imsize when X is a matrix."""
    tmp = []
    numimgs = len(X)

    # create a list of images (reshape if necessary)
    for i in range(0, numimgs):
        if imsize != None:
            tmp.append(X[i].reshape(imsize))
        else:
            tmp.append(squeeze(X[i]))

    # add blanks
    if (numimgs > maxw) and (mod(numimgs, maxw) > 0):
        leftover = maxw - mod(numimgs, maxw)
        meanimg = 0.5 * (X[0].max() + X[0].min())
        for i in range(0, leftover):
            tmp.append(ones(tmp[0].shape) * meanimg)

    # make the montage
    tmp2 = []
    for i in range(0, len(tmp), maxw):
        tmp2.append(hstack(tmp[i:i + maxw]))
    montimg = vstack(tmp2)
    return montimg


# show images in a plot
def show_imgs(W_list, nc=10, highlight_green=None, highlight_red=None, titles=None):
    # nc is the number of columns
    nfilter = len(W_list)
    nr = (nfilter - 1) // nc + 1
    for i in range(nr):
        for j in range(nc):
            idx = i * nc + j
            if idx == nfilter:
                break
            plt.subplot(nr, nc, idx + 1)
            cur_W = W_list[idx]
            plt.imshow(cur_W, cmap='gray', interpolation='nearest')
            if titles is not None:
                if isinstance(titles, str):
                    plt.title(titles.format(idx))
                else:
                    plt.title(titles[idx])

            if ((highlight_green is not None) and highlight_green[idx]) or (
                    (highlight_red is not None) and highlight_red[idx]):
                ax = plt.gca()
                if highlight_green[idx]:
                    mycol = '#00FF00'
                else:
                    mycol = 'r'
                for S in ['bottom', 'top', 'right', 'left']:
                    ax.spines[S].set_color(mycol)
                    ax.spines[S].set_lw(2.0)
                ax.xaxis.set_ticks_position('none')
                ax.yaxis.set_ticks_position('none')
                ax.set_xticks([])
                ax.set_yticks([])
            else:
                plt.gca().set_axis_off()


# show a few images
plt.figure(figsize=(9, 4))
plt.imshow(image_montage(trainI[trainYb[:, 0] == 1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

plt.figure(figsize=(9, 4))
plt.imshow(image_montage(trainI[trainYb[:, 1] == 1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

# %% [markdown]
# Next we will generate the training/validation set from the training data.

# %%
# generate fixed validation set of 10% of the training set
vtrainI, validI, vtrainYb, validYb = model_selection.train_test_split(trainI, trainYb,
                                                                      train_size=0.9, test_size=0.1, random_state=4488)

# make validation data
validsetI = (validI, validYb)

print(vtrainI.shape)
print(validI.shape)
# Out:
# (6279, 19, 19, 1)
# (698, 19, 19, 1)

# %% [markdown]
# Here are some useful functions.

# %%
def plot_history(history):
    fig, ax1 = plt.subplots()

    ax1.plot(history.history['loss'], 'r', label="training loss ({:.6f})".format(history.history['loss'][-1]))
    ax1.plot(history.history['val_loss'], 'r--',
             label="validation loss ({:.6f})".format(history.history['val_loss'][-1]))
    ax1.grid(True)
    ax1.set_xlabel('iteration')
    ax1.legend(loc="best", fontsize=9)
    ax1.set_ylabel('loss', color='r')
    ax1.tick_params('y', colors='r')

    if 'accuracy' in history.history:
        ax2 = ax1.twinx()

        ax2.plot(history.history['accuracy'], 'b',
                 label="training acc ({:.4f})".format(history.history['accuracy'][-1]))
        ax2.plot(history.history['val_accuracy'], 'b--',
                 label="validation acc ({:.4f})".format(history.history['val_accuracy'][-1]))

        ax2.legend(loc="best", fontsize=9)
        ax2.set_ylabel('acc', color='b')
        ax2.tick_params('y', colors='b')

# %% [markdown]
# Now let's try a simple logistic regression classifier, trained using Keras. Since the inputs are images, we will convert the input image into a vector using the "Flatten" layer first.

# %%
# initialize random seed
K.clear_session()
random.seed(4487);
tf.random.set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19, 19, 1)))  # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',  # use validation accuracy for stopping
    min_delta=0.0001, patience=5,
    verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
           metrics=['accuracy']  # also calculate accuracy during training
           )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50,
                 callbacks=callbacks_list,
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 9: early stopping
# test accuracy: 0.6101694915254238

# %% [markdown]
# ## 2. Detection using CNN
#
# Train an CNN to classify an image patch as face or not face.  Use  `vtrainI` and `vtrainY` as the training set and `validsetI` as the validation set.  You can try different architectures, and adjust values of the learning rates, number of iterations, early stopping, regularization, etc. to get a good result.  Use a large batch size (e.g., 50) to speed up the training time.  Remember to add the `callbacks` so that you can monitor the training process.

# %%
### INSERT YOUR CODE HERE

def SCNN():
    # build the network
    nn = Sequential()
    nn.add(Conv2D(10, (5, 5), strides=(2, 2), activation='relu', padding='same', input_shape=(19, 19, 1)))
    nn.add(Conv2D(40, (5, 5), strides=(2, 2), activation='relu', padding='same'))
    nn.add(Flatten())
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=2, activation='softmax'))
    return nn


def DCNN():
    # build the network
    nn = Sequential()
    nn.add(Conv2D(10, (5, 5), strides=(2, 2), activation='relu', padding='same', input_shape=(19, 19, 1)))
    nn.add(Conv2D(40, (5, 5), strides=(2, 2), activation='relu', padding='same'))
    nn.add(Flatten())
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=2, activation='softmax'))
    return nn

# %%
def train_CNN(nn, lr, delta):
    # initialize random seed
    K.clear_session();
    random.seed(4487)
    tf.random.set_seed(4487)
    # early stopping criteria
    earlystop = keras.callbacks.EarlyStopping(
        monitor='val_accuracy',  # use validation accuracy for stopping
        min_delta=delta, patience=10,
        verbose=1, mode='auto')
    callbacks_list = [earlystop]
    # compile and fit the network
    nn.compile(loss=keras.losses.categorical_crossentropy,
               optimizer=keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True),
               metrics=['accuracy'])
    history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50,
                     callbacks=callbacks_list,
                     validation_data=validsetI, verbose=False)
    predY = argmax(nn.predict(testI, verbose=False), axis=-1)
    acc = metrics.accuracy_score(testY, predY)
    print("test accuracy:", acc)

# %%
nn = SCNN()
for lr in [0.1, 0.01, 0.001, 0.0001, 0.00001]:
    train_CNN(nn, lr, 0.0001)

for delta in [0.1, 0.01, 0.001, 0.0001, 0.00001]:
    train_CNN(nn, 0.01, delta)
# Out:
# Epoch 20: early stopping
# test accuracy: 0.6694915254237288
# Epoch 13: early stopping
# test accuracy: 0.6694915254237288
# Epoch 11: early stopping
# test accuracy: 0.6694915254237288
# Epoch 11: early stopping
# test accuracy: 0.6694915254237288
# Epoch 11: early stopping
# test accuracy: 0.6694915254237288
# Epoch 11: early stopping
# test accuracy: 0.6684322033898306
# Epoch 11: early stopping
# test accuracy: 0.6684322033898306
# Epoch 11: early stopping
# test accuracy: 0.6684322033898306
# Epoch 11: early stopping
# test accuracy: 0.6684322033898306
# Epoch 11: early stopping
# test accuracy: 0.6684322033898306

# %%
nn = DCNN()
for lr in [0.1, 0.01, 0.001, 0.0001, 0.00001]:
    train_CNN(nn, lr, 0.0001)

for delta in [0.1, 0.01, 0.001, 0.0001, 0.00001]:
    train_CNN(nn, 0.01, delta)
# Out:
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5
# Epoch 11: early stopping
# test accuracy: 0.5

# %% [markdown]
# _How does the MLP compare to the linear and non-linear classifiers that you tried in Tutorial 4?_
# - **INSERT YOUR ANSWER HERE**
# 1. Using CNN layer, MLP can extract coarse and fine-grained features of the image. Thus, it can be capped higher in terms of performance.
# 2. MLP has a much better ability to learn the information in the CNN extracted features, and many good results will occur.
# 3. CNN-based MLP can be extended to a very deep structure.
#
# - Performance:
# 1) architectures
#  Compare with Test ACC
#  1 Conv2D + 1 Dense = 0.5
#  1 Conv2D + 2 Dense = 0.5
#  2 Conv2D + 1 Dense = 0.598
#  2 Conv2D + 2 Dense = 0.6186
#  2 Conv2D + 3 Dense = 0.739
#  3 Conv2D + 2 Dense = 0.6758
#
# 2) learning rate
#     Compare with Test ACC AND Conv2D + 3 Dense
#     lr = 0.1 = 0.739
#     lr = 0.01 = 0.667
#     lr = 0.001 = 0.663
#     lr = 0.0001 = 0.663
#     lr = 0.00001 = 0.663
# 3) delta
#     Compare with Test ACC AND Conv2D + 3 Dense
#     delta = 0.1 = 0.663
#     delta = 0.01 = 0.663
#     delta = 0.001 = 0.663
#     delta = 0.0001 = 0.663
#     delta = 0.00001 = 0.665

# %% [markdown]
# ## 3. Data Augmentation
#
# Now use data augmentation (introduced in the last tutorial) to try to improve the accuracy.

# %% [markdown]
# We can also add per-pixel noise or transformations. We define a few functions for adding per-pixel noise.  The following functions will add Gaussian pixel noise, add corruption noise (setting some input pixels to 0), scale and shift pixel values (changing contrast and brightness).

# %%
def add_gauss_noise(X, sigma2=0.05):
    # add Gaussian noise with zero mean, and variance sigma2
    return X + random.normal(0, sigma2, X.shape)


def add_corrupt_noise(X, p=0.1):
    # apply pixel corruption (zero out value) with probability p
    return X * random.binomial(1, 1 - p, X.shape)


def add_scale_shift(X, sigma2=0.1, alpha2=0.2):
    # randomly scale and shift the pixel values (same for each image)
    # Xnew = a X + b
    # a is sampled from a Gaussian with mean 1, and variance sigma2
    # b is sampled from a Gaussian with mean 0, and variance alpha2
    if X.ndim == 3:
        dshape = (X.shape[0], 1, 1)
    elif X.ndim == 4:
        dshape = (X.shape[0], 1, 1, 1)
    else:
        dshape = (1,)
    a = random.normal(1, sigma2, dshape)
    b = random.normal(0, alpha2, dshape)
    return minimum(maximum(a * X + b, 0.0), 1.0)

# %% [markdown]
# Next, we define a function for adding per-pixel noise (in this case just Gaussian noise). The noise is included using the `preprocessing_function` input of the `ImageDataGenerator`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)


# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,  # image rotation
    width_shift_range=0.05,  # image shifting
    height_shift_range=0.05,  # image shifting
    shear_range=0.05,  # shear transformation
    zoom_range=0.05,  # zooming
    horizontal_flip=True,  # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

# %% [markdown]
# Next we can show some examples of augmented images. Run the code below to see different random augmentations.

# %%
img = trainI[4]
imgs = [img[:, :, 0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1, 19, 19, 1), [1], batch_size=1):
    imgs.append(augimg[0, :, :, 0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8, 6))
show_imgs(imgs, nc=3, titles=titles)

# %% [markdown]
# The augmented images look similar to the original image, but contain small differences that the network can use to learn more about the class.

# %% [markdown]
# Now let's try training logistic regression with data augmentation. Instead of "fit", we now  use the "fit_generator" method, which will pass each input through the ImageDataGenerator before sending it to the MLP.  We also disable early stopping so that the training sees more augmented data.

# %%
# initialize random seed
K.clear_session()
random.seed(4487)
tf.random.set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19, 19, 1)))  # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',  # use validation accuracy for stopping
    min_delta=0.0001, patience=5,
    verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
           metrics=['accuracy']  # also calculate accuracy during training
           )

# fit with data generator
history = nn.fit(
    datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
    steps_per_epoch=len(vtrainI) / 50,  # should be number of batches per epoch
    epochs=50,
    #           callbacks=callbacks_list,
    validation_data=validsetI, verbose=True)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2286 - accuracy: 0.9014 - val_loss: 0.1070 - val_accuracy: 0.9556
# Epoch 2/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1779 - accuracy: 0.9259 - val_loss: 0.1110 - val_accuracy: 0.9628
# Epoch 3/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1600 - accuracy: 0.9330 - val_loss: 0.1836 - val_accuracy: 0.9255
# Epoch 4/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1615 - accuracy: 0.9315 - val_loss: 0.1211 - val_accuracy: 0.9513
# Epoch 5/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1620 - accuracy: 0.9336 - val_loss: 0.1170 - val_accuracy: 0.9527
# Epoch 6/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1568 - accuracy: 0.9385 - val_loss: 0.1498 - val_accuracy: 0.9355
# Epoch 7/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1617 - accuracy: 0.9357 - val_loss: 0.1017 - val_accuracy: 0.9613
# Epoch 8/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1542 - accuracy: 0.9400 - val_loss: 0.0986 - val_accuracy: 0.9628
# Epoch 9/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1596 - accuracy: 0.9363 - val_loss: 0.1249 - val_accuracy: 0.9470
# Epoch 10/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1624 - accuracy: 0.9323 - val_loss: 0.0907 - val_accuracy: 0.9628
# Epoch 11/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1515 - accuracy: 0.9419 - val_loss: 0.1526 - val_accuracy: 0.9312
# Epoch 12/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1608 - accuracy: 0.9382 - val_loss: 0.1607 - val_accuracy: 0.9255
# Epoch 13/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1554 - accuracy: 0.9411 - val_loss: 0.1119 - val_accuracy: 0.9513
# Epoch 14/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1487 - accuracy: 0.9416 - val_loss: 0.1281 - val_accuracy: 0.9370
# Epoch 15/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1570 - accuracy: 0.9388 - val_loss: 0.0912 - val_accuracy: 0.9628
# Epoch 16/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1545 - accuracy: 0.9382 - val_loss: 0.1038 - val_accuracy: 0.9599
# Epoch 17/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1558 - accuracy: 0.9385 - val_loss: 0.0940 - val_accuracy: 0.9656
# Epoch 18/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1558 - accuracy: 0.9379 - val_loss: 0.1053 - val_accuracy: 0.9570
# Epoch 19/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1464 - accuracy: 0.9439 - val_loss: 0.0961 - val_accuracy: 0.9585
# Epoch 20/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1543 - accuracy: 0.9411 - val_loss: 0.1260 - val_accuracy: 0.9427
# Epoch 21/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1525 - accuracy: 0.9408 - val_loss: 0.1011 - val_accuracy: 0.9585
# Epoch 22/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1584 - accuracy: 0.9371 - val_loss: 0.1399 - val_accuracy: 0.9312
# Epoch 23/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1570 - accuracy: 0.9404 - val_loss: 0.1082 - val_accuracy: 0.9499
# Epoch 24/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1575 - accuracy: 0.9390 - val_loss: 0.0903 - val_accuracy: 0.9656
# Epoch 25/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1506 - accuracy: 0.9371 - val_loss: 0.2013 - val_accuracy: 0.9241
# Epoch 26/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1575 - accuracy: 0.9376 - val_loss: 0.0871 - val_accuracy: 0.9642
# Epoch 27/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1475 - accuracy: 0.9420 - val_loss: 0.0963 - val_accuracy: 0.9570
# Epoch 28/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1546 - accuracy: 0.9390 - val_loss: 0.1080 - val_accuracy: 0.9556
# Epoch 29/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1481 - accuracy: 0.9430 - val_loss: 0.1266 - val_accuracy: 0.9427
# Epoch 30/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1500 - accuracy: 0.9431 - val_loss: 0.1118 - val_accuracy: 0.9542
# Epoch 31/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1523 - accuracy: 0.9420 - val_loss: 0.1419 - val_accuracy: 0.9398
# Epoch 32/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1568 - accuracy: 0.9403 - val_loss: 0.2135 - val_accuracy: 0.9212
# Epoch 33/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1566 - accuracy: 0.9360 - val_loss: 0.0800 - val_accuracy: 0.9699
# Epoch 34/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1542 - accuracy: 0.9403 - val_loss: 0.0903 - val_accuracy: 0.9628
# Epoch 35/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1544 - accuracy: 0.9376 - val_loss: 0.1133 - val_accuracy: 0.9513
# Epoch 36/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1565 - accuracy: 0.9388 - val_loss: 0.1104 - val_accuracy: 0.9499
# Epoch 37/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1571 - accuracy: 0.9395 - val_loss: 0.0905 - val_accuracy: 0.9628
# Epoch 38/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1529 - accuracy: 0.9388 - val_loss: 0.1074 - val_accuracy: 0.9527
# Epoch 39/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1555 - accuracy: 0.9408 - val_loss: 0.1343 - val_accuracy: 0.9441
# Epoch 40/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1583 - accuracy: 0.9379 - val_loss: 0.1068 - val_accuracy: 0.9556
# Epoch 41/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1499 - accuracy: 0.9409 - val_loss: 0.0844 - val_accuracy: 0.9656
# Epoch 42/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1468 - accuracy: 0.9430 - val_loss: 0.0915 - val_accuracy: 0.9613
# Epoch 43/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1536 - accuracy: 0.9352 - val_loss: 0.0812 - val_accuracy: 0.9656
# Epoch 44/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1456 - accuracy: 0.9435 - val_loss: 0.0999 - val_accuracy: 0.9556
# Epoch 45/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1550 - accuracy: 0.9404 - val_loss: 0.0861 - val_accuracy: 0.9628
# Epoch 46/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1502 - accuracy: 0.9406 - val_loss: 0.0899 - val_accuracy: 0.9585
# Epoch 47/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1539 - accuracy: 0.9408 - val_loss: 0.1104 - val_accuracy: 0.9499
# Epoch 48/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1557 - accuracy: 0.9403 - val_loss: 0.1431 - val_accuracy: 0.9327
# Epoch 49/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1472 - accuracy: 0.9423 - val_loss: 0.1134 - val_accuracy: 0.9470
# Epoch 50/50
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1555 - accuracy: 0.9357 - val_loss: 0.1310 - val_accuracy: 0.9355

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.7584745762711864

# %% [markdown]
# Using data augmentation, the test accuracy improves from 0.622 to 0.692! (your numbers may be different)

# %% [markdown]
# Now train your best CNN from the previous section using data augmentation.
# Try different per-pixel noise levels, and different options of the ImageDataGenerator (see [here](https://keras.io/preprocessing/image/)),
# and combinations of them.  Hopefully you should be able to improve the accuracy!

# %%
### INSERT YOUR CODE HERE ###

# %%
from tqdm import tqdm

# gauss corrupt shift
def addGuassNoise1(X):
    return add_gauss_noise(X, 0.1)
def addGuassNoise2(X):
    return add_gauss_noise(X, 0.2)
def addGuassNoise3(X):
    return add_gauss_noise(X, 0.3)

def addCorruptNoise1(X):
    return add_corrupt_noise(X, p=0.1)
def addCorruptNoise2(X):
    return add_corrupt_noise(X, p=0.2)
def addCorruptNoise3(X):
    return add_corrupt_noise(X, p=0.3)

def addScaleShift1(X):
    return add_scale_shift(X,sigma2=0.1, alpha2=0.2)
def addScaleShift2(X):
    return add_scale_shift(X,sigma2=0.2, alpha2=0.2)
def addScaleShift3(X):
    return add_scale_shift(X,sigma2=0.2, alpha2=0.3)
def addScaleShift4(X):
    return add_scale_shift(X,sigma2=0.3, alpha2=0.3)
def addScaleShift5(X):
    return add_scale_shift(X,sigma2=0.3, alpha2=0.4)
def addScaleShift6(X):
    return add_scale_shift(X,sigma2=0.4, alpha2=0.4)

comb1 = lambda x : addGuassNoise1(addCorruptNoise1(x))
comb2 = lambda x : addGuassNoise1(addScaleShift1(x))
comb3 = lambda x : addCorruptNoise1(addScaleShift1(x))
comb4 = lambda x : addGuassNoise1(addCorruptNoise1(addScaleShift1(x)))

# %%
def DCNN():
    # build the network
    nn = Sequential()
    nn.add(Conv2D(10, (5, 5), strides=(2, 2), activation='relu', padding='same', input_shape=(19, 19, 1)))
    nn.add(Conv2D(40, (5, 5), strides=(2, 2), activation='relu', padding='same'))
    nn.add(Flatten())
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=50, activation='relu'))
    nn.add(Dense(units=2, activation='softmax'))
    return nn

# %%
addNoise_arr = [addGuassNoise1, addGuassNoise2, addGuassNoise3, addCorruptNoise1, addCorruptNoise2, addCorruptNoise3, addScaleShift1, addScaleShift2, addScaleShift3, addScaleShift4, addScaleShift5, addScaleShift6, comb1, comb2, comb3, comb4]

for addNoise in tqdm(addNoise_arr):
    # build the data augmenter
    datagen = ImageDataGenerator(
        rotation_range=10,         # image rotation
        width_shift_range=0.05,     # image shifting
        height_shift_range=0.05,    # image shifting
        shear_range=0.05,           # shear transformation
        zoom_range=0.05,            # zooming
        horizontal_flip=True,       # horizontal flipping
        preprocessing_function=addNoise,  # add per-pixel noise
        data_format='channels_last')

    K.clear_session()
    random.seed(4487)
    tf.random.set_seed(4487)
    # build the network for logistic regression
    nn = DCNN()
    earlystop = keras.callbacks.EarlyStopping(
                monitor='val_accuracy',             # use validation accuracy for stopping
                min_delta=0.00001, patience=10,
                verbose=1, mode='auto')
    # compile and fit the network
    nn.compile(loss=keras.losses.categorical_crossentropy,
            optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True),
            metrics=['accuracy']  # also calculate accuracy during training
            )
    # fit with data generator
    history = nn.fit_generator(
                datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
                steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
                epochs=50,
                validation_data=validsetI, verbose=False)

    # plot_history(history)
    predY = argmax(nn.predict(testI, verbose=False), axis=-1)
    acc = metrics.accuracy_score(testY, predY)
    print("test accuracy, NN with au: {:.3f}".format(acc) )
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#   6%|▋         | 1/16 [01:17<19:28, 77.89s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.851
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  12%|█▎        | 2/16 [02:31<17:38, 75.63s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.873
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  19%|█▉        | 3/16 [04:00<17:37, 81.38s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.867
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  25%|██▌       | 4/16 [05:26<16:42, 83.51s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.817
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  31%|███▏      | 5/16 [06:55<15:38, 85.29s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.844
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  38%|███▊      | 6/16 [08:22<14:19, 85.94s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.780
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  44%|████▍     | 7/16 [09:50<12:58, 86.53s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.817
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  50%|█████     | 8/16 [11:14<11:25, 85.74s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.818
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  56%|█████▋    | 9/16 [12:37<09:53, 84.85s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.804
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  62%|██████▎   | 10/16 [13:55<08:16, 82.78s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.774
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  69%|██████▉   | 11/16 [15:16<06:51, 82.22s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.793
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  75%|███████▌  | 12/16 [16:34<05:23, 80.86s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.810
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  81%|████████▏ | 13/16 [17:46<03:55, 78.42s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.878
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  88%|████████▊ | 14/16 [19:00<02:33, 76.83s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.791
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
#  94%|█████████▍| 15/16 [20:35<01:22, 82.37s/it]WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# test accuracy, NN with au: 0.827
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\3047276972.py:30: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = nn.fit_generator(
# 100%|██████████| 16/16 [22:14<00:00, 83.43s/it]
# test accuracy, NN with au: 0.873

# %% [markdown]
# _How does CNN with data augmentation compare with your work in Tutorial 8?_
# - **INSERT YOUR ANSWER HERE**
# - CNN performs even better than Corrupt noise in distinguishing Gaussian noise because of the recognition of different granularity information. And the performance is not much degraded on the combined noise.
# - Performance.
# - Gaussian noise: [0.1, 0.2, 0.3] = [0.851, 0.873, 0.867]
# - Corrupt noise: [0.1, 0.2, 0.3] = [0.817, 0.844, 0.780]
# - Scale shift: [0.1,0.2; 0.2,0.2; 0.2,0.3;0.3,0.3;0.3,0.4;0.4,0.4] = [0.817, 0.818, 0.804, 0.6774, 0.793, 0.810]
# - Combination: [1, 2, 3, 4] = [0.878, 0.791, 0.827, 0.873]

# %% [markdown]
# # Test image
# Now lets try your face detector on a real image.  Download the "nasa-small.png" image and put it in the same directory as your ipynb file.  The below code will load the image, crop out image patches and then extract features. (this may take a few minutes)

# %%
fname = "nasa-small.png"

# %%
# load image
testimg = skimage.io.imread(fname, as_gray=True)
print(testimg.shape)
plt.imshow(testimg, cmap='gray')
# Out:
# (210, 480)

# %%
# step size for the sliding window
step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg, (19, 19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0] * psize[1], psize[2], psize[3], 1))
print(patches2.shape)

# histogram equalize patches (improves contrast)
#newI = empty(patches2.shape)
#for i in range(patches2.shape[0]):
#    newI[i,:,:] = skimage.exposure.equalize_hist(patches2[i,:,:])
newI = patches2
# Out:
# (5568, 19, 19, 1)

# %% [markdown]
# Now predict using your classifier.  The extracted images are in `newI`.

# %%
### YOUR CODE HERE
prednewY = argmax(nn.predict(newI), axis=-1)
# Out:
# 174/174 [==============================] - 1s 3ms/step

# %% [markdown]
# Now we we will view the results on the image.  Use the below code. `prednewY` is the vector of predictions.

# %%
# reshape prediction to an image
imgY = prednewY.reshape(psize[0], psize[1])

# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0], 9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg.shape[0] - imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0], testimg.shape[1] - imgY2.shape[1]))))

# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1 - imgY2
tmp = nimgY2 * testimg
detimg = dstack((imgY2 + tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9, 9))
plt.subplot(2, 1, 1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2, 1, 2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\2017234307.py:5: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# (-0.5, 479.5, 209.5, -0.5)

# %% [markdown]
# _How did your face detector do compared to the last version?_
# - **INSERT YOUR ANSWER HERE**
# - Compared to the MLP face is basically found and just located in the nose part, the performance is very good. However, multiple faces are still detected in dense areas near the face.

# %% [markdown]
# You can try it on your own images.  The faces should all be around 19x19 pixels though. We only used 1/8 of the training data. Try using more data to train it!

# %%
fname = "ai.jpeg"
testimg2 = skimage.io.imread(fname, as_gray=True)

# convert to grayscale
print(testimg2.shape)
plt.imshow(testimg2, cmap='gray')

step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg2, (19,19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0]*psize[1], psize[2], psize[3], 1))

newI = patches2
prednewY = argmax(nn.predict(newI, verbose=False), axis=-1)

imgY = prednewY.reshape(psize[0], psize[1])
# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0],9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg2.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg2.shape[0]-imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg2.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0],testimg2.shape[1]-imgY2.shape[1]))))

# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1-imgY2
tmp = nimgY2*testimg2
detimg = dstack((imgY2+tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2,1,2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# (792, 1000)
# C:\Users\yingyinyu3\AppData\Local\Temp\ipykernel_18540\108118223.py:21: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 999.5, 791.5, -0.5)
